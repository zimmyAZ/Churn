# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from scipy import stats
from pandas import DataFrame
from pandas.tools.plotting import scatter_matrix
import random
print('Done')
# Out:
# Done

# %%
userdata = pd.read_csv('../churn/user_logs_v2.csv')
membdata = pd.read_csv('../churn/members_v3.csv')
trandata = pd.read_csv('../churn/transactions_v2.csv')
is_churn = pd.read_csv('../churn/train_v2.csv')
print('Done')
# Out:
# Done

# %%
merged = pd.merge(userdata, trandata, on='msno')
merged = pd.merge(merged, membdata, on ='msno')
merged = pd.merge(merged, is_churn, on ='msno')
test_set = merged[12000000:15000000]
merged = merged[0:12000000]
merged = merged.sample(frac=1)
test_set = test_set.sample(frac=1)
print('Done')
# Out:
# Done

# %%
dates_test = DataFrame(test_set['msno'], columns=['msno'])
dates_test['registration_year'] = test_set['registration_init_time'].astype(str).str[:4]
dates_test['registration_month'] = test_set['registration_init_time'].astype(str).str[4:6]
dates_test['registration_day'] = test_set['registration_init_time'].astype(str).str[6:8]
dates_test.set_index('msno')
# Out:
#                                              registration_year  \
# msno
# vmjlzdpfIiAm/t7SmiMkDjeiwCWNI0sBrMUwbPoFZlc=              2014
# Ctfa1O5vKPqojXh0nOYEeVZ+T1pb8xHnJ93SfiN7+qU=              2015
# kggJoN7DoN+f5p9acqY4VmXiVqVvtqG7a9JIQlu9mIo=              2013
# hQirtFbRr8t5T+/aVbrXM2tRNvoOIzChx5qzm1v/PE0=              2015
# GUJwea8/w2+J6UomDPATqI3Gkk5EZvY9/tGzeXzblY8=              2010
# MrJZIyQaOm8WkTkCzMsL5ZsUq+EN4TJVykCPIZcmAKQ=              2016
# WPoiTJ0uNrokufwxmLOr5arPGoXSrlzqXYhVJOxuva8=              2010
# UhVaMBHtBu2seRJHSo109YksJnMRyw0omM4/f0K4GgQ=              2011
# jjCtGIHB3vIaWGDC0FjBmyDf04v9vBqJrRuQqdtafDQ=              2012
# 5XN+5hHHRRfyPnKe/jKIroCF7txOAEO1ngkE2OUVowQ=              2016
# Mnsg8HuOs3XcZxO8QdUKonJixnb8HsUZf9qylneMgyM=              2016
# Wzx1gHXLuLiNGkkLGA0mBMsEPDClGWrjcCUS2qo7vQg=              2016
# Vc+HueNBrEV1qeB38ldJgadANs5lhjfBXgtnsgo5XBw=              2016
# 22rApuAh06DjBEdm8F5NGGakf7mM8dKHKWanavG8hrY=              2010
# XWfmP2XusVjc/RI6CAsRKSSYn8dc/6He9oTSwzBiF4Q=              2011
# RwEcJEN6Wqr0/INCdNdyK1eoIVfvg4tOxlsVZF1CQTk=              2015
# 0OuJ2LUlJcSsco4SR7tPC89Y29xHT7va0oUQTjrVGiY=              2011
# g8gAChvnBxrPlnYXODncbgdwHgb3jdrU9IyfXnLtoMw=              2011
# nnatVIwG11emX5dPXcl/ehiBpFV6y2KtDDHVgm7p8Io=              2016
# MEwpJ3LRWixVHMFGF49HRtVn6ecTRTo2fp54CuGOLpo=              2007
# mI+Ip5o4LOS5nWr6kQuxQO5hvX4jaWRPzRm/X2p/UBk=              2014
# fb+vdlleoxvN3yp8dlmFGg78TzVqjpD6Ly/h8WCuCvc=              2012
# fjxqOhkr3vXCY5MlGHDjUqpHbn4khKlXRvifsALmJ2g=               24
# TM39tVpGu/zTav/hvFKyXY706iACidMRjE83ANqOQ8g=               05
# o7BToOzP17pYEI+FRtW/VAgITL1k9XPE9MJV+EuX7vo=               05
# SXPWM20fbnFHyqg27883uG/DlmXDDgs6GLnmBp2Ygy4=               28
# VmY379ybDbqzUaX9PQN8DJKD3+cEruM7hoh/SqRbh18=               11
# WcV++wticYbwJQJSxjZwkaUBL70ch2tWXMHE6+uJZmg=               10
# 4wU0BwEftl8Pyq2o5naIclw03zipkX4J/iRaHf5bMDo=               23
# nKG7kVlOxvARXuBWQ77g5nYr4aFU1xf06cSxgOAW0EY=               22
# z87VLW8+YBNH2qRDme6hvk8Ngo1TfDV4UKqM5F0slc8=               09
# 3AeFMgSBER4FRscjd75cpa289Pmq+fuv65C9ZYEsp8Q=               23
# b6D1rMGgD4FlPxhmucVTHvO0WQPq14zTwzfhl2ArG0s=               08
# 47hthfxcWWLyW/NuaOlcTHRx6oTFowjuWO3skObtkpk=               25
# ZM9jnUqnMSMlfrzyp5VZDiuTJ4MvbfqGbY8Q9vglFwQ=               15
# LQcrVstRLqupscwNI7qhnjBJNlux4ZyBzIub6XkgxqU=               30
# MWGp6xDu9yRrNguLSTF794luC3g0Ml7Q1GQogj+6k+c=               12
# tBRuh5D2fCzaV1uG43pvwH/67A2jJWeFaywgzu2ZrOI=               28
# p+OT7vhgWSiWKCfZmkWZWhkgen0Hhjqp8yaswAGhEq0=               16
# SM+XvGko2BmM1A+50EBd0Fd0XyPfPk25A37euxJW3AM=               17
# kzOEzsIGpB0M0Le2HJmqhiDGNM7e2G+/jl1xvOisuSM=               15
# iTxkjKh95iB75n9v4UACeJHVoCL6prsFXGBH6VbPqF4=               24
# lGgV7gvr/r43BkOwDUYeTXgbDsiDWwbxk+aJ3oSq/dU=               19
# QL1N6/JvM8gj/+U3f207Q+TAU7IFmrmFLlaldk/Fgik=               21
# xuXbKcuKjKTeP9UESie6MSdC2d2O84x2eSTBoHI2GaI=               30
# Vp9nxvosUC8UASuvVSPdADuRz9aRw61d/agkf0mcEQE=               31
# YTgtg2MlcuFYc3BAqYbiwUFC5J3uT9ULAJzReTmmI/Q=               17
# aEe1tt8Okcqp1qR+gSNlsasgSQAKTfkvTVw8reb89sM=               01
# gQPSpf0shwaroqvntFxZXgU6GUROK+f7NI1HBjPpm7o=               13
#
# [3000000 rows x 3 columns]

# %%
test_set.fillna(0)
# merged.drop('date', axis=1, inplace=True)
# merged.drop('transaction_date', axis=1, inplace=True)
# merged.drop('membership_expire_date', axis=1, inplace=True)
# merged.drop('registration_init_time', axis=1, inplace=True)
test_set.set_index('msno').sum()
print('Done')
# Out:
# Done

# %%
test_nums = DataFrame(test_set['msno'], columns=['msno'])
test_cancelled = DataFrame(test_set['msno'], columns=['msno'])
test_cancelled['is_churn'] = test_set['is_churn'].convert_objects(convert_numeric=True)
test_nums['num_25'] = test_set['num_25'].convert_objects(convert_numeric=True)
test_nums['num_50'] = test_set['num_50'].convert_objects(convert_numeric=True)
test_nums['num_75'] = test_set['num_75'].convert_objects(convert_numeric=True)
test_nums['num_985'] = test_set['num_985'].convert_objects(convert_numeric=True)
test_nums['num_100'] = test_set['num_100'].convert_objects(convert_numeric=True)
test_nums['num_unq'] = test_set['num_unq'].convert_objects(convert_numeric=True)
test_nums['total_secs'] = test_set['total_secs'].convert_objects(convert_numeric=True)
test_nums['actual_amount_paid'] = test_set['actual_amount_paid'].convert_objects(convert_numeric=True)
test_nums['start_year'] = dates_test['registration_year'].convert_objects(convert_numeric=True)
test_nums['start_month'] = dates_test['registration_month'].convert_objects(convert_numeric=True)
test_nums['start_day'] = dates_test['registration_day'].convert_objects(convert_numeric=True)
test_nums['date'] = test_set['date'].convert_objects(convert_numeric=True)
test_nums['transaction_date'] = test_set['transaction_date'].convert_objects(convert_numeric=True)
test_nums['membership_expire_date'] = test_set['membership_expire_date'].convert_objects(convert_numeric=True)
test_nums['registration_init_time'] = test_set['registration_init_time'].convert_objects(convert_numeric=True)
test_nums.set_index('msno')
test_cancelled.set_index('msno')
test_nums.drop('msno', axis=1, inplace=True)
test_cancelled.drop('msno', axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   import sys
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:11: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   del sys.path[0]
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:18: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
dates = DataFrame(merged['msno'], columns=['msno'])
dates['registration_year'] = merged['registration_init_time'].astype(str).str[:4]
dates['registration_month'] = merged['registration_init_time'].astype(str).str[4:6]
dates['registration_day'] = merged['registration_init_time'].astype(str).str[6:8]
dates.set_index('msno')
# Out:
#                                              registration_year  \
# msno
# M1lUaIcbuKQBxotlZQ6dUz5gm67IDSKiE6OeSoNhvOY=              2010
# UzQI5Di/XgY0Mm5wncN4OEKy7CJi+MaNvAmcAZfvrNo=              2006
# DQCYrD6OhtIQGqPtVnnTwaprBZ5rkGSTo7YBmLN0/Mg=              2012
# QphEgW76niNwI0RofhSGAIiftECexRZNHLyWXkee5PQ=              2017
# XavBugNpfuXxBlsg03Q32JYLZYd3MbwgFbAP8VqR+EY=              2016
# HrM7ubU3h8QtTjPi17QXEEonhyfelQBIm85WZOQJs3Y=              2013
# mUUQ2l9xvWzkdQmTb679lYPV0goIVm8Jgzp9+btwjqk=              2013
# Y19KNzHm/25t9CA23o7ThkPXgzZ2Lhu6ncCq7nIulUE=              2015
# LyBYwF1JP/IMTTQcGxuOff0/o5FPg3HWzZJ7Gf+GI3c=              2014
# 8RPLf4RWh2WK6WSY/iI0vQEsd5FjNrI5IHBcwAnjpGw=              2006
# 5rQmm6QDZ08uMZ1HFy4c8SfWO+eBLzmzulIgrBspRj8=              2015
# rRMbuLad85SrAMQtse8JhZwANluOtpAqi1XrHrkJa/g=              2016
# mobYMN7JQUQCZ6pv+PVxOIps8hwH5ihVEYmqc1mhVw8=              2011
# CoGPfm/3BQz8PrKWWn6CObyJ0JzFaQo8xLVJGPWVtjc=              2011
# KjAB7pRjhULV8Pt2nZT9mJFubYRHZl0acXtF7vnEf7o=              2007
# 9JReVYxpkAtK+LpdWa/qwdZftoiCGz5ZVoC/u5smh60=              2007
# JkB3G+y22fYuq3KmJFZ/6CCP26u4aZt02wjHpbQEjS8=              2015
# OGbaUPnJG4pfvDOj1rNu3SMo29WiYUSWEjN9HpvUsR8=               21
# YKSHEqrOKzEOWhKMgKMv1Uuzu6qKDUJFUKuoda3NfNw=               18
# XgjWvx3gwbZNkJAO0jrgMIb6Ohj3Rmfa29okdZYWrmg=               28
# ...                                                       ...
# MJwTFOkgxLd59FTqsZl/1wK/0QPcIWkm9ONOOciBM0E=               13
# iPuM7yN7c0VVtX8RYa+pxp6ZdtqX3furQAU/ui+nXkM=               18
# MUO6QaaWtaMd2QFAbC8c1oOSp9fHP3c5Illfdqxi6P8=               17
# 80RN7KU9RgoulfWee9svsjokh7tc0hKptaGn/Np7ttA=               07
# cIGw4gSyYsPsvpSf89+qbWOPA6OY+TgIewA+1aPKFXY=               16
# N6sIItpcBftU5D2JfYDiMrSYFcRs3Ms8dCxVnpJK0AY=               09
# h/vSDVubQY41/J2JA/v+FxEsQJPucIbMLMY83d8EpxU=               15
# FBQwfzvUlZsnqrfWOxsUI2Y25suwqPdS+JAOyNjpwuM=               06
# aM3Tx8kobKWvlDiqqia9WjcIUWtTrh427U0WAjAZVoU=               04
# 5+L8snCFEpubbM+bCaFPNaDrDKn1dMsw1Mvsv8ZOBZQ=               30
# Xo+/ukaP3uHoWZj36xl1UxvK/bhf6MMruaafGc/YKF4=               08
# tJu807ku2ORrC6sU8B/HiAUMCz92E4bDQvy5m2VLzM0=               21
# MYhubOjk2FF3QtdDDPPeRWjf3q0aBlEDmlimPdVQHd4=               22
# guUx7SY56QNknRtk6aoDXfUJ8p4H2WLb5bpWLcj9JuI=               20
# plXhq9bJbWOA0PFGU3ImMp6sbeGsI1PAZ1ai796eqik=               14
# 0/fKuwmoql/pdzMZN1sEm+mv+WfHWOIfqW9UpWel5gk=               12
# bWNP0ruYFnBydopdoizrJA/iUbsawctmGbGMoIZTzWs=               23
# fxR8nM2XksZ46L25jeDDPyk52+M0FnWDt9l6YBkxPxU=               02
# E6trAZWLDwKsPnx8JlnU0JMzhGUK7U6187SSs95TBmk=               10
# 01qsMndQZQpObvMGdZinp4s5XI/6EdjdxbY7Wdn1ge8=               21
# wGfN1Z9x8ohzzggtJpWznnL0C4dn6rlm4vaDQBWh+Lk=               03
# ZD3dSZ+zOMzPjh9m2OPRsKzdSk8xGaSMErJOwNxmmb0=               16
# lzu9BWXLSuzRhAXF+iizmpHpBxkoUb+Vfue5IEtUiNU=               21
# D8Bn4CHx8B5oxew+SlWLi4kQPkcKbD1iKUtXqyDCpBE=               29
# Sm2YlMqwWocvsaZ5WYXOjxwnJFGbOnvqnPwRKnGrZMg=               31
# XGy3rVAIRJlynxsCDfhcHE8+A930GPhhh4kfCCsQ7PY=               04
# KoLjT2Ci58qwwwF+yHNnTLAFFUeg7hnKBte0Mo6mfU0=               10
# LZXmVIJYz3f9D4OM5Xd8YenX2B87kY60WuepCyol9pk=               18
# QepKyQ29AT/POK1HXT+WFVj0Pv/sAvgZmj9D/H6XrKA=               09
# C18lWMKu+ScfHzE6guBVO1+mmK3GZq1OU0UBGH7UvZo=               01
#
# [12000000 rows x 3 columns]

# %%
merged.fillna(0)
# merged.drop('date', axis=1, inplace=True)
# merged.drop('transaction_date', axis=1, inplace=True)
# merged.drop('membership_expire_date', axis=1, inplace=True)
# merged.drop('registration_init_time', axis=1, inplace=True)
merged.set_index('msno').sum()
print('Done')

# %%
add_nums = DataFrame(merged['msno'], columns=['msno'])
cancelled = DataFrame(merged['msno'], columns=['msno'])
cancelled['is_churn'] = merged['is_churn'].convert_objects(convert_numeric=True)
add_nums['num_25'] = merged['num_25'].convert_objects(convert_numeric=True)
add_nums['num_50'] = merged['num_50'].convert_objects(convert_numeric=True)
add_nums['num_75'] = merged['num_75'].convert_objects(convert_numeric=True)
add_nums['num_985'] = merged['num_985'].convert_objects(convert_numeric=True)
add_nums['num_100'] = merged['num_100'].convert_objects(convert_numeric=True)
add_nums['num_unq'] = merged['num_unq'].convert_objects(convert_numeric=True)
add_nums['total_secs'] = merged['total_secs'].convert_objects(convert_numeric=True)
add_nums['actual_amount_paid'] = merged['actual_amount_paid'].convert_objects(convert_numeric=True)
add_nums['start_year'] = dates['registration_year'].convert_objects(convert_numeric=True)
add_nums['start_month'] = dates['registration_month'].convert_objects(convert_numeric=True)
add_nums['start_day'] = dates['registration_day'].convert_objects(convert_numeric=True)
add_nums['date'] = merged['date'].convert_objects(convert_numeric=True)
add_nums['transaction_date'] = merged['transaction_date'].convert_objects(convert_numeric=True)
add_nums['membership_expire_date'] = merged['membership_expire_date'].convert_objects(convert_numeric=True)
add_nums['registration_init_time'] = merged['registration_init_time'].convert_objects(convert_numeric=True)
add_nums.set_index('msno')
cancelled.set_index('msno')
add_nums.drop('msno', axis=1, inplace=True)
cancelled.drop('msno', axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   import sys
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:11: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   del sys.path[0]
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:18: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
# add_nums.drop('msno', axis=1, inplace=True)
# cancelled.drop('msno', axis=1, inplace=True)
X = add_nums[0:10000].values
y = cancelled[0:10000].values
x_scaled = min_max_scaler.fit_transform(X)
y_scaled = min_max_scaler.fit_transform(y)
X = x_scaled
y = y_scaled

def sigmoid(x):
    output = 1/(1+np.exp(-x))
    return output

def deriv(x):
    return x*(1-x)

np.random.seed(1)

# syn_best = 11 x 6 x 4 x 2 x 1

syn0 = 2*np.random.random((15,10)) - 1
syn1 = 2*np.random.random((10,10)) - 1
syn2 = 2*np.random.random((10,5)) - 1
syn3 = 2*np.random.random((5,1)) - 1

# alpha_best = 0.01(lowest start) or .001(fast drop)

alpha = .005
epoch = 100000

def train(X, y, syn0, syn1, syn2, syn3, alpha):
    
    for iter in range(epoch):
        
        l0 = X
        l1 = sigmoid(np.dot(l0, syn0))
        l2 = sigmoid(np.dot(l1, syn1))
        l3 = sigmoid(np.dot(l2, syn2))
        l4 = sigmoid(np.dot(l3, syn3))

        l4_error = l4 - y
        l4_delta = l4_error * deriv(l4)
        
        l3_error = l4_delta.dot(syn3.T)
        l3_delta = l3_error * deriv(l3)
        
        l2_error = l3_delta.dot(syn2.T)
        l2_delta = l2_error * deriv(l2)

        l1_error = l2_delta.dot(syn1.T)
        l1_delta = l1_error * deriv(l1)

        syn0 -= alpha * (l0.T.dot(l1_delta))
        syn1 -= alpha * (l1.T.dot(l2_delta))
        syn2 -= alpha * (l2.T.dot(l3_delta))
        syn3 -= alpha * (l3.T.dot(l4_delta))
        
        if(iter % 10000) == 0:
            print('Epoch: ' + str(iter))
            print('Error: ' + str(np.mean(np.abs(l4_error))))
            
    print("Output after training:")
    print(l4)
            
train(X, y, syn0, syn1, syn2, syn3, alpha)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-cb83644d00df> in <module>()
#       3 min_max_scaler = preprocessing.MinMaxScaler()
#       4 add_nums.drop('msno', axis=1, inplace=True)
# ----> 5 cancelled.drop('msno', axis=1, inplace=True)
#       6 X = add_nums[0:10000].values
#       7 y = cancelled[0:10000].values
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
#    3626         return self.delete(indexer)
#
# ValueError: labels ['msno'] not contained in axis

# %%
weight_1 = syn0
weight_2 = syn1
weight_3 = syn2
weight_4 = syn3
train(X, y, weight_1, weight_2, weight_3,weight_4, alpha)

# %%
def test(x, syn0, syn1, syn2, syn3):
    l0 = x
    l1 = sigmoid(np.dot(l0, syn0))
    l2 = sigmoid(np.dot(l1, syn1))
    l3 = sigmoid(np.dot(l2, syn2))
    l4 = sigmoid(np.dot(l3, syn3))
    print('Predictied: ' + str(l4))

# %%
from random import randint
random_guy = randint(0, len(cancelled))
print(random_guy)

test_guy = add_nums[random_guy-1:random_guy].values
good = cancelled[random_guy-1:random_guy].values


# test_scaled.drop('msno',  axis=1, inplace=True)
print(test_guy)
print('Actual: ' + str(good))
test(test_guy, syn0, syn1, syn2, syn3)
# Out:
# 195518
# [['/9ZRf53bd8S8AdIrlBtov/h6n8qSenxO5V9BAsYdh4o=' 1 2 3 3 29 35 7996.458 149
#   2006 3 7 20170317 20170331 20170430 20060307]]
# Actual: [[0]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-10e128a8fb2c> in <module>()
#      10 print(test_guy)
#      11 print('Actual: ' + str(good))
# ---> 12 test(test_guy, syn0, syn1, syn2, syn3)
#
# <ipython-input-20-351825056991> in test(x, syn0, syn1, syn2, syn3)
#       1 def test(x, syn0, syn1, syn2, syn3):
#       2     l0 = x
# ----> 3     l1 = sigmoid(np.dot(l0, syn0))
#       4     l2 = sigmoid(np.dot(l1, syn1))
#       5     l3 = sigmoid(np.dot(l2, syn2))
#
# ValueError: shapes (1,16) and (15,10) not aligned: 16 (dim 1) != 15 (dim 0)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_jobs=2, random_state=0)
clf.fit(add_nums, cancelled)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=2, oob_score=False, random_state=0,
#             verbose=0, warm_start=False)

# %%
from random import randint
random_guy = randint(0, len(test_cancelled))
print(random_guy)
print(clf.predict(test_nums[random_guy:random_guy+1]))
print(test_cancelled[random_guy:random_guy+1])
print(clf.score(add_nums, cancelled))
# Out:
# 568456
# [0]
#          is_churn
# 2094946         0
# 0.999865
